# %%
import numpy as np
from react_scatter_board import ReactScatterBoard

# %%
pts = [
    dict(
        x=x, y=y, z=z,
        uniform=np.random.uniform(),
        normal=np.random.normal(),
        binary=np.random.randint(2),
        discrete=np.random.randint(10),
    )
    for x,y,z in np.random.normal(0, 5, size=(1000,3))
]
ReactScatterBoard(is3d=True, data=pts)
# Out:
# <div id="66888263-dad3-4683-b804-ae92e2c9f802"></div>
# <script>
# require(['react_scatter_board'], function (react_scatter_board) {
#   var self = document.getElementById('66888263-dad3-4683-b804-ae92e2c9f802')
#   while (self.children.length > 0) self.children[0].remove()
#   react_scatter_board.ReactScatterBoard(
#     self,
# ...
